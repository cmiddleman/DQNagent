# %%
import numpy as np 
import matplotlib.pyplot as plt 
import gym
from statistics import mean, median
from collections import Counter
from env import TicTacToe
import env
from itertools import product

from room import Game_Handler
from network import Network
from agents import DQNAgent, HumanAgent, one_hot_encode
X=1
O=-1
BOARD_LENGTH=3

# %%
import numba
from numba import jit

# %%
game_handler = Game_Handler(num_agents=2)

# %%
for agent in game_handler.agent_corpus:
    agent.explore = False

# %%
import cProfile
import re

# %%
def f(x):
    return x + 1

def g(x):
    return 2*x

# %%
@profile
def play():
    for _ in range(100):
        game_handler.play_game(players={X: game_handler.agent_corpus[0], O:game_handler.agent_corpus[1]})
        for agent in game_handler.agent_corpus:
            agent.learn()

# %%
play()
# Out:
#          24273081 function calls (23885054 primitive calls) in 51.713 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002   51.757   51.757 <ipython-input-17-953992ffb551>:1(play)
#      1003    0.003    0.000   43.042    0.043 /home/chase/Desktop/Galvanize/capstone2/src/agents.py:134(q)
#      1003    0.047    0.000   42.833    0.043 /home/chase/Desktop/Galvanize/capstone2/src/agents.py:138(predict)
#      1003    0.086    0.000   42.310    0.042 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1593(predict)
#      1167    0.005    0.000   32.817    0.028 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1361(get_data_handler)
#      1167    0.029    0.000   32.812    0.028 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1098(__init__)
# ...

# %%
play()
# Out:
#          2844820 function calls (2799230 primitive calls) in 5.016 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    5.019    5.019 <ipython-input-63-502790c03ec9>:1(play)
#       114    0.005    0.000    4.112    0.036 /home/chase/Desktop/Galvanize/capstone2/src/agents.py:130(q)
#       114    0.009    0.000    4.038    0.035 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1593(predict)
#       134    0.000    0.000    3.216    0.024 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1361(get_data_handler)
#       134    0.003    0.000    3.216    0.024 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1098(__init__)
# ...

# %%
len(agentX.memory)
# Out:
# 16283

# %%
play()
# Out:
#          290970 function calls (285848 primitive calls) in 0.582 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.582    0.582 <ipython-input-32-6710dd3515fc>:1(play)
#        12    0.001    0.000    0.486    0.040 /home/chase/Desktop/Galvanize/capstone2/src/agents.py:130(q)
#        12    0.001    0.000    0.477    0.040 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1593(predict)
#        14    0.000    0.000    0.368    0.026 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1361(get_data_handler)
#        14    0.000    0.000    0.368    0.026 /home/chase/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py:1098(__init__)
# ...

# %%
import cProfile, pstats, io



def profile(fnc):
    
    """A decorator that uses cProfile to profile a function"""
    
    def inner(*args, **kwargs):
        
        pr = cProfile.Profile()
        pr.enable()
        retval = fnc(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval

    return inner
